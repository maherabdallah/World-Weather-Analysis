# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 619

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | kapaa
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | bredasdorp
# Processing Record 4 of Set 13 | guerrero negro
# Processing Record 5 of Set 13 | sosenskiy
# Processing Record 6 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 13 | hermosillo
# Processing Record 8 of Set 13 | talnakh
# Processing Record 9 of Set 13 | nikolskoye
# Processing Record 10 of Set 13 | hermanus
# Processing Record 11 of Set 13 | castro
# Processing Record 12 of Set 13 | mataura
# Processing Record 13 of Set 13 | butaritari
# Processing Record 14 of Set 13 | jamestown
# Processing Record 15 of Set 13 | dikson
# Processing Record 16 of Set 13 | yellowknife
# Processing Record 17 of Set 13 | srednekolymsk
# Processing Record 18 of Set 13 | hobart
# Processing Record 19 of Set 13 | norman wells
# Processing Record 20 of Set 13 | ilo
# Processing Record 21 of Set 13 | hithadhoo
# Processing Record 22 of Set 13 | leningradskiy
# Processing Record 23 of Set 13 | broome
# Processing Record 24 of Set 13 | henties bay
# Processing Record 25 of Set 13 | punta arenas
# Processing Record 26 of Set 13 | arlit
# Processing Record 27 of Set 13 | ushuaia
# Processing Record 28 of Set 13 | saskylakh
# Processing Record 29 of Set 13 | busselton
# Processing Record 30 of Set 13 | bambous virieux
# Processing Record 31 of Set 13 | arraial do cabo
# Processing Record 32 of Set 13 | bluff
# Processing Record 33 of Set 13 | omsukchan
# Processing Record 34 of Set 13 | georgetown
# Processing Record 35 of Set 13 | port elizabeth
# Processing Record 36 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 13 | barrow
# Processing Record 38 of Set 13 | pangnirtung
# Processing Record 39 of Set 13 | hilo
# Processing Record 40 of Set 13 | cape town
# Processing Record 41 of Set 13 | dehloran
# Processing Record 42 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 13 | canto do buriti
# Processing Record 44 of Set 13 | neepawa
# Processing Record 45 of Set 13 | severo-kurilsk
# Processing Record 46 of Set 13 | todos santos
# Processing Record 47 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 13 | albany
# Processing Record 49 of Set 13 | vaini
# Processing Record 50 of Set 13 | el astillero
# Processing Record 1 of Set 14 | praia da vitoria
# Processing Record 2 of Set 14 | uaua
# Processing Record 3 of Set 14 | homer
# Processing Record 4 of Set 14 | puerto ayora
# Processing Record 5 of Set 14 | laramie
# Processing Record 6 of Set 14 | nemuro
# Processing Record 7 of Set 14 | pontes e lacerda
# Processing Record 8 of Set 14 | osmena
# Processing Record 9 of Set 14 | geraldton
# Processing Record 10 of Set 14 | pisco
# Processing Record 11 of Set 14 | sembe
# Processing Record 12 of Set 14 | meulaboh
# Processing Record 13 of Set 14 | hofn
# Processing Record 14 of Set 14 | torbay
# Processing Record 15 of Set 14 | khatanga
# Processing Record 16 of Set 14 | shigony
# Processing Record 17 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 14 | sambava
# Processing Record 19 of Set 14 | half moon bay
# Processing Record 20 of Set 14 | pilar
# Processing Record 21 of Set 14 | avarua
# Processing Record 22 of Set 14 | rikitea
# Processing Record 23 of Set 14 | beringovskiy
# Processing Record 24 of Set 14 | saint-philippe
# Processing Record 25 of Set 14 | waitati
# Processing Record 26 of Set 14 | longyearbyen
# Processing Record 27 of Set 14 | kruisfontein
# Processing Record 28 of Set 14 | lata
# Processing Record 29 of Set 14 | kompaniyivka
# Processing Record 30 of Set 14 | mar del plata
# Processing Record 31 of Set 14 | sola
# Processing Record 32 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 14 | loiza
# Processing Record 34 of Set 14 | san patricio
# Processing Record 35 of Set 14 | east london
# Processing Record 36 of Set 14 | valparaiso
# Processing Record 37 of Set 14 | gorom-gorom
# Processing Record 38 of Set 14 | nanortalik
# Processing Record 39 of Set 14 | kholm
# Processing Record 40 of Set 14 | dongsheng
# Processing Record 41 of Set 14 | la asuncion
# Processing Record 42 of Set 14 | ancud
# Processing Record 43 of Set 14 | necochea
# Processing Record 44 of Set 14 | green river
# Processing Record 45 of Set 14 | port alfred
# Processing Record 46 of Set 14 | lucapa
# Processing Record 47 of Set 14 | uyemskiy
# Processing Record 48 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 14 | uzhur
# Processing Record 1 of Set 15 | damaturu
# Processing Record 2 of Set 15 | olafsvik
# Processing Record 3 of Set 15 | allanridge
# Processing Record 4 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 15 | new norfolk
# Processing Record 6 of Set 15 | senno
# Processing Record 7 of Set 15 | yulara
# Processing Record 8 of Set 15 | carnarvon
# Processing Record 9 of Set 15 | lebu
# Processing Record 10 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 15 | almaty
# Processing Record 12 of Set 15 | maldonado
# Processing Record 13 of Set 15 | axim
# Processing Record 14 of Set 15 | kota kinabalu
# Processing Record 15 of Set 15 | jurado
# Processing Record 16 of Set 15 | ukiah
# Processing Record 17 of Set 15 | izmit
# Processing Record 18 of Set 15 | tuktoyaktuk
# Processing Record 19 of Set 15 | rumphi
# Processing Record 20 of Set 15 | tarakan
# Processing Record 21 of Set 15 | qaanaaq
# Processing Record 22 of Set 15 | saint-augustin
# Processing Record 23 of Set 15 | vagur
# Processing Record 24 of Set 15 | dunedin
# Processing Record 25 of Set 15 | apricena
# Processing Record 26 of Set 15 | avera
# Processing Record 27 of Set 15 | mandalgovi
# Processing Record 28 of Set 15 | ilhabela
# Processing Record 29 of Set 15 | arvin
# Processing Record 30 of Set 15 | shuangcheng
# Processing Record 31 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 15 | thompson
# Processing Record 33 of Set 15 | monatele
# City not found. Skipping...
# Processing Record 34 of Set 15 | andenes
# Processing Record 35 of Set 15 | myaundzha
# Processing Record 36 of Set 15 | forbes
# Processing Record 37 of Set 15 | anadyr
# Processing Record 38 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 15 | maniitsoq
# Processing Record 40 of Set 15 | kavieng
# Processing Record 41 of Set 15 | los llanos de aridane
# Processing Record 42 of Set 15 | north bend
# Processing Record 43 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 15 | kilmez
# City not found. Skipping...
# Processing Record 45 of Set 15 | tura
# Processing Record 46 of Set 15 | bethel
# Processing Record 47 of Set 15 | ostrovnoy
# Processing Record 48 of Set 15 | ribeira grande
# Processing Record 49 of Set 15 | bulanash
# Processing Record 50 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 16 | kununurra
# Processing Record 2 of Set 16 | temiscaming
# Processing Record 3 of Set 16 | changping
# Processing Record 4 of Set 16 | port hardy
# Processing Record 5 of Set 16 | garissa
# Processing Record 6 of Set 16 | faya
# Processing Record 7 of Set 16 | ponta do sol
# Processing Record 8 of Set 16 | moose factory
# Processing Record 9 of Set 16 | gazojak
# Processing Record 10 of Set 16 | suihua
# Processing Record 11 of Set 16 | kaeo
# Processing Record 12 of Set 16 | szczecin
# Processing Record 13 of Set 16 | mount gambier
# Processing Record 14 of Set 16 | provideniya
# Processing Record 15 of Set 16 | atuona
# Processing Record 16 of Set 16 | atar
# Processing Record 17 of Set 16 | dingle
# Processing Record 18 of Set 16 | bourail
# Processing Record 19 of Set 16 | kaitangata
# Processing Record 20 of Set 16 | isangel
# Processing Record 21 of Set 16 | columbus
# Processing Record 22 of Set 16 | popondetta
# Processing Record 23 of Set 16 | arman
# Processing Record 24 of Set 16 | yenagoa
# Processing Record 25 of Set 16 | souillac
# Processing Record 26 of Set 16 | kismayo
# Processing Record 27 of Set 16 | saint-francois
# Processing Record 28 of Set 16 | carrollton
# Processing Record 29 of Set 16 | suzun
# Processing Record 30 of Set 16 | brookhaven
# Processing Record 31 of Set 16 | kalomo
# City not found. Skipping...
# Processing Record 32 of Set 16 | sorland
# Processing Record 33 of Set 16 | banjar
# Processing Record 34 of Set 16 | kamphaeng phet
# Processing Record 35 of Set 16 | victoria
# Processing Record 36 of Set 16 | hobyo
# Processing Record 37 of Set 16 | canberra
# Processing Record 38 of Set 16 | nelson
# Processing Record 39 of Set 16 | kamaishi
# Processing Record 40 of Set 16 | alenquer
# Processing Record 41 of Set 16 | grindavik
# Processing Record 42 of Set 16 | esperance
# Processing Record 43 of Set 16 | ahipara
# Processing Record 44 of Set 16 | nishihara
# Processing Record 45 of Set 16 | nanakuli
# Processing Record 46 of Set 16 | havre-saint-pierre
# Processing Record 47 of Set 16 | warrnambool
# Processing Record 48 of Set 16 | port blair
# Processing Record 49 of Set 16 | tshikapa
# Processing Record 50 of Set 16 | kungurtug
# Processing Record 1 of Set 17 | luba
# Processing Record 2 of Set 17 | chamba
# Processing Record 3 of Set 17 | pevek
# Processing Record 4 of Set 17 | merrill
# Processing Record 5 of Set 17 | iskateley
# Processing Record 6 of Set 17 | hasaki
# Processing Record 7 of Set 17 | fortuna
# Processing Record 8 of Set 17 | zheleznodorozhnyy
# Processing Record 9 of Set 17 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 17 | kirakira
# Processing Record 11 of Set 17 | tombouctou
# Processing Record 12 of Set 17 | sergeyevka
# Processing Record 13 of Set 17 | cuenca
# Processing Record 14 of Set 17 | sibu
# Processing Record 15 of Set 17 | pinega
# Processing Record 16 of Set 17 | tuatapere
# Processing Record 17 of Set 17 | tiznit
# Processing Record 18 of Set 17 | bonavista
# Processing Record 19 of Set 17 | siderno
# Processing Record 20 of Set 17 | ichinohe
# Processing Record 21 of Set 17 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 17 | northam
# Processing Record 23 of Set 17 | vila velha
# Processing Record 24 of Set 17 | college
# Processing Record 25 of Set 17 | daru
# Processing Record 26 of Set 17 | port augusta
# Processing Record 27 of Set 17 | soe
# Processing Record 28 of Set 17 | helena
# Processing Record 29 of Set 17 | sao joao da barra
# Processing Record 30 of Set 17 | oranjestad
# Processing Record 31 of Set 17 | cherskiy
# Processing Record 32 of Set 17 | asadabad
# Processing Record 33 of Set 17 | taoudenni
# Processing Record 34 of Set 17 | alofi
# Processing Record 35 of Set 17 | edison
# Processing Record 36 of Set 17 | laguna
# Processing Record 37 of Set 17 | ilulissat
# Processing Record 38 of Set 17 | san cristobal
# Processing Record 39 of Set 17 | la ronge
# Processing Record 40 of Set 17 | lavrentiya
# Processing Record 41 of Set 17 | yar-sale
# Processing Record 42 of Set 17 | adrar
# Processing Record 43 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 17 | tanete
# Processing Record 45 of Set 17 | kloulklubed
# Processing Record 46 of Set 17 | ituni
# City not found. Skipping...
# Processing Record 47 of Set 17 | antalaha
# Processing Record 48 of Set 17 | verkhoyansk
# Processing Record 49 of Set 17 | kahului
# Processing Record 50 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 18 | kunming
# Processing Record 2 of Set 18 | cidreira
# Processing Record 3 of Set 18 | payo
# Processing Record 4 of Set 18 | innisfail
# Processing Record 5 of Set 18 | barra patuca
# Processing Record 6 of Set 18 | kugesi
# Processing Record 7 of Set 18 | lianzhou
# Processing Record 8 of Set 18 | bengkulu
# Processing Record 9 of Set 18 | lorengau
# Processing Record 10 of Set 18 | brae
# Processing Record 11 of Set 18 | kambove
# Processing Record 12 of Set 18 | asau
# Processing Record 13 of Set 18 | nova olimpia
# Processing Record 14 of Set 18 | santa maria
# Processing Record 15 of Set 18 | caravelas
# Processing Record 16 of Set 18 | mount isa
# Processing Record 17 of Set 18 | sitka
# Processing Record 18 of Set 18 | saldanha
# Processing Record 19 of Set 18 | helong
# Processing Record 20 of Set 18 | tasiilaq
# Processing Record 21 of Set 18 | jinchang
# Processing Record 22 of Set 18 | meoqui
# Processing Record 23 of Set 18 | karratha
# Processing Record 24 of Set 18 | chokurdakh
# Processing Record 25 of Set 18 | whyalla
# Processing Record 26 of Set 18 | sabla
# Processing Record 27 of Set 18 | lucea
# Processing Record 28 of Set 18 | vardo
# Processing Record 29 of Set 18 | windsor
# Processing Record 30 of Set 18 | high level
# Processing Record 31 of Set 18 | kodiak
# Processing Record 32 of Set 18 | pilani
# Processing Record 33 of Set 18 | hirara
# Processing Record 34 of Set 18 | dunmore town
# Processing Record 35 of Set 18 | springbok
# Processing Record 36 of Set 18 | kinkala
# Processing Record 37 of Set 18 | nha trang
# Processing Record 38 of Set 18 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 18 | fuyu
# Processing Record 40 of Set 18 | gillette
# Processing Record 41 of Set 18 | coihaique
# Processing Record 42 of Set 18 | bintulu
# Processing Record 43 of Set 18 | labuhan
# Processing Record 44 of Set 18 | adra
# Processing Record 45 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 18 | uglovka
# Processing Record 47 of Set 18 | port-gentil
# Processing Record 48 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 18 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 18 | anori
# Processing Record 1 of Set 19 | ambulu
# Processing Record 2 of Set 19 | amambai
# Processing Record 3 of Set 19 | neiafu
# Processing Record 4 of Set 19 | bilma
# Processing Record 5 of Set 19 | port antonio
# Processing Record 6 of Set 19 | zhengjiatun
# Processing Record 7 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 19 | aquiraz
# Processing Record 9 of Set 19 | mahebourg
# Processing Record 10 of Set 19 | lagoa
# Processing Record 11 of Set 19 | cayenne
# Processing Record 12 of Set 19 | pestovo
# Processing Record 13 of Set 19 | newport
# Processing Record 14 of Set 19 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 19 | kalmunai
# Processing Record 16 of Set 19 | lamu
# Processing Record 17 of Set 19 | kisesa
# Processing Record 18 of Set 19 | alberton
# Processing Record 19 of Set 19 | lompoc
# Processing Record 20 of Set 19 | ushtobe
# Processing Record 21 of Set 19 | jalu
# Processing Record 22 of Set 19 | bandar-e lengeh
# Processing Record 23 of Set 19 | sioux lookout
# Processing Record 24 of Set 19 | darnah
# Processing Record 25 of Set 19 | sechura
# Processing Record 26 of Set 19 | airai
# Processing Record 27 of Set 19 | denpasar
# Processing Record 28 of Set 19 | las cruces
# Processing Record 29 of Set 19 | halifax
# Processing Record 30 of Set 19 | alice springs
# Processing Record 31 of Set 19 | alyangula
# Processing Record 32 of Set 19 | rocha
# Processing Record 33 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 19 | taunggyi
# Processing Record 35 of Set 19 | baykit
# Processing Record 36 of Set 19 | phuket
# Processing Record 37 of Set 19 | the pas
# Processing Record 38 of Set 19 | clyde river
# Processing Record 39 of Set 19 | rockingham
# Processing Record 40 of Set 19 | gallup
# Processing Record 41 of Set 19 | nantucket
# Processing Record 42 of Set 19 | miramar
# Processing Record 43 of Set 19 | salinopolis
# Processing Record 44 of Set 19 | southwick
# Processing Record 45 of Set 19 | tostedt
# Processing Record 46 of Set 19 | vikhorevka
# Processing Record 47 of Set 19 | nikolayevsk-na-amure
# Processing Record 48 of Set 19 | south valley
# Processing Record 49 of Set 19 | velyka bahachka
# Processing Record 50 of Set 19 | burica
# City not found. Skipping...
# Processing Record 1 of Set 20 | mahenge
# Processing Record 2 of Set 20 | amapa
# Processing Record 3 of Set 20 | iquique
# Processing Record 4 of Set 20 | vostok
# Processing Record 5 of Set 20 | ambon
# Processing Record 6 of Set 20 | buchmany
# Processing Record 7 of Set 20 | narsaq
# Processing Record 8 of Set 20 | marzuq
# Processing Record 9 of Set 20 | hamilton
# Processing Record 10 of Set 20 | cartagena
# Processing Record 11 of Set 20 | upernavik
# Processing Record 12 of Set 20 | cap malheureux
# Processing Record 13 of Set 20 | viedma
# Processing Record 14 of Set 20 | borskoye
# Processing Record 15 of Set 20 | yucca valley
# Processing Record 16 of Set 20 | bereda
# Processing Record 17 of Set 20 | palmer
# Processing Record 18 of Set 20 | road town
# Processing Record 19 of Set 20 | staryy nadym
# Processing Record 20 of Set 20 | muli
# Processing Record 21 of Set 20 | iqaluit
# Processing Record 22 of Set 20 | kazachinskoye
# Processing Record 23 of Set 20 | harnosand
# Processing Record 24 of Set 20 | birecik
# Processing Record 25 of Set 20 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 20 | ndele
# Processing Record 27 of Set 20 | zhanakorgan
# Processing Record 28 of Set 20 | san felipe
# Processing Record 29 of Set 20 | te anau
# Processing Record 30 of Set 20 | san luis
# Processing Record 31 of Set 20 | cabo san lucas
# Processing Record 32 of Set 20 | wittingen
# Processing Record 33 of Set 20 | umm lajj
# Processing Record 34 of Set 20 | kostroma
# Processing Record 35 of Set 20 | gaoual
# Processing Record 36 of Set 20 | saint george
# Processing Record 37 of Set 20 | rio grande
# Processing Record 38 of Set 20 | marsh harbour
# Processing Record 39 of Set 20 | ayr
# Processing Record 40 of Set 20 | montbrison
# Processing Record 41 of Set 20 | visby
# Processing Record 42 of Set 20 | novikovo
# Processing Record 43 of Set 20 | gobabis
# Processing Record 44 of Set 20 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 45 of Set 20 | fuxin
# Processing Record 46 of Set 20 | ola
# Processing Record 47 of Set 20 | sabang
# Processing Record 48 of Set 20 | porto belo
# Processing Record 49 of Set 20 | kavaratti
# Processing Record 50 of Set 20 | sitio novo do tocantins
# Processing Record 1 of Set 21 | ronneby
# Processing Record 2 of Set 21 | usinsk
# Processing Record 3 of Set 21 | touros
# Processing Record 4 of Set 21 | boden
# Processing Record 5 of Set 21 | vao
# Processing Record 6 of Set 21 | isla vista
# Processing Record 7 of Set 21 | dicabisagan
# Processing Record 8 of Set 21 | seoul
# Processing Record 9 of Set 21 | jabiru
# City not found. Skipping...
# Processing Record 10 of Set 21 | naze
# Processing Record 11 of Set 21 | sokoni
# Processing Record 12 of Set 21 | kayasula
# Processing Record 13 of Set 21 | alexandria
# Processing Record 14 of Set 21 | komsomolskiy
# Processing Record 15 of Set 21 | synya
# Processing Record 16 of Set 21 | boromo
# Processing Record 17 of Set 21 | hami
# Processing Record 18 of Set 21 | kiama
# Processing Record 19 of Set 21 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 21 | barcelos
# Processing Record 21 of Set 21 | san carlos
# Processing Record 22 of Set 21 | menongue
# Processing Record 23 of Set 21 | safranbolu
# Processing Record 24 of Set 21 | opuwo
# Processing Record 25 of Set 21 | whitehorse
# Processing Record 26 of Set 21 | boa vista
# Processing Record 27 of Set 21 | hattiesburg
# Processing Record 28 of Set 21 | winslow
# Processing Record 29 of Set 21 | poncitlan
# Processing Record 30 of Set 21 | muzhi
# Processing Record 31 of Set 21 | jilotzingo
# Processing Record 32 of Set 21 | sawakin
# Processing Record 33 of Set 21 | salalah
# Processing Record 34 of Set 21 | mehamn
# Processing Record 35 of Set 21 | kachikau
# City not found. Skipping...
# Processing Record 36 of Set 21 | safwah
# City not found. Skipping...
# Processing Record 37 of Set 21 | barcelona
# Processing Record 38 of Set 21 | ye
# City not found. Skipping...
# Processing Record 39 of Set 21 | vila franca do campo
# Processing Record 40 of Set 21 | xinqing
# Processing Record 41 of Set 21 | okha
# Processing Record 42 of Set 21 | kachiry
# Processing Record 43 of Set 21 | havoysund
# Processing Record 44 of Set 21 | strezhevoy
# Processing Record 45 of Set 21 | lowestoft
# Processing Record 46 of Set 21 | kabalo
# Processing Record 47 of Set 21 | cueramaro
# Processing Record 48 of Set 21 | pengcheng
# Processing Record 49 of Set 21 | weiser
# Processing Record 50 of Set 21 | naryan-mar
# Processing Record 1 of Set 22 | rangoon
# Processing Record 2 of Set 22 | korla
# Processing Record 3 of Set 22 | tara
# Processing Record 4 of Set 22 | rafaela
# Processing Record 5 of Set 22 | mabua
# Processing Record 6 of Set 22 | flinders
# Processing Record 7 of Set 22 | maltahohe
# Processing Record 8 of Set 22 | hagenow
# Processing Record 9 of Set 22 | ankang
# Processing Record 10 of Set 22 | chiredzi
# Processing Record 11 of Set 22 | hambantota
# Processing Record 12 of Set 22 | margate
# Processing Record 13 of Set 22 | zhigansk
# Processing Record 14 of Set 22 | yining
# Processing Record 15 of Set 22 | salta
# Processing Record 16 of Set 22 | north platte
# Processing Record 17 of Set 22 | klaksvik
# Processing Record 18 of Set 22 | general roca
# Processing Record 19 of Set 22 | camacha
# Processing Record 20 of Set 22 | awassa
# Processing Record 21 of Set 22 | watsa
# Processing Record 22 of Set 22 | san carlos de bariloche
# Processing Record 23 of Set 22 | campbellton
# Processing Record 24 of Set 22 | voineasa
# Processing Record 25 of Set 22 | pringsewu
# Processing Record 26 of Set 22 | aklavik
# Processing Record 27 of Set 22 | coahuayana
# Processing Record 28 of Set 22 | gamba
# Processing Record 29 of Set 22 | pontianak
# Processing Record 30 of Set 22 | tyazhinskiy
# Processing Record 31 of Set 22 | tambun
# Processing Record 32 of Set 22 | honiara
# Processing Record 33 of Set 22 | cabedelo
# Processing Record 34 of Set 22 | severnyy
# Processing Record 35 of Set 22 | kaoma
# Processing Record 36 of Set 22 | paungde
# Processing Record 37 of Set 22 | okhotsk
# Processing Record 38 of Set 22 | faanui
# Processing Record 39 of Set 22 | goderich
# Processing Record 40 of Set 22 | muravlenko
# Processing Record 41 of Set 22 | juba
# Processing Record 42 of Set 22 | krasnyy yar
# Processing Record 43 of Set 22 | harper
# Processing Record 44 of Set 22 | tiksi
# Processing Record 45 of Set 22 | hellin
# Processing Record 46 of Set 22 | del rio
# Processing Record 47 of Set 22 | saint-denis
# Processing Record 48 of Set 22 | coquimbo
# Processing Record 49 of Set 22 | shalakusha
# Processing Record 50 of Set 22 | vestmannaeyjar
# Processing Record 1 of Set 23 | kerema
# Processing Record 2 of Set 23 | anloga
# Processing Record 3 of Set 23 | fort nelson
# Processing Record 4 of Set 23 | luderitz
# Processing Record 5 of Set 23 | neuquen
# Processing Record 6 of Set 23 | yurginskoye
# Processing Record 7 of Set 23 | gusinoye ozero
# Processing Record 8 of Set 23 | stykkisholmur
# Processing Record 9 of Set 23 | rawson
# Processing Record 10 of Set 23 | nexo
# Processing Record 11 of Set 23 | nizhniy baskunchak
# Processing Record 12 of Set 23 | xai-xai
# Processing Record 13 of Set 23 | salina
# Processing Record 14 of Set 23 | hays
# Processing Record 15 of Set 23 | southbridge
# Processing Record 16 of Set 23 | baie-comeau
# Processing Record 17 of Set 23 | port lincoln
# Processing Record 18 of Set 23 | emba
# Processing Record 19 of Set 23 | hay river
# Processing Record 20 of Set 23 | sakaiminato
# Processing Record 21 of Set 23 | phan thiet
# Processing Record 22 of Set 23 | shimoda
# Processing Record 23 of Set 23 | berlevag
# Processing Record 24 of Set 23 | okandja
# City not found. Skipping...
# Processing Record 25 of Set 23 | kulhudhuffushi
# Processing Record 26 of Set 23 | makakilo city
# Processing Record 27 of Set 23 | olden
# Processing Record 28 of Set 23 | fare
# Processing Record 29 of Set 23 | jibuti
# Processing Record 30 of Set 23 | lima
# Processing Record 31 of Set 23 | collie
# Processing Record 32 of Set 23 | paita
# Processing Record 33 of Set 23 | viransehir
# Processing Record 34 of Set 23 | lucani
# Processing Record 35 of Set 23 | zhuhai
# Processing Record 36 of Set 23 | moussoro
# Processing Record 37 of Set 23 | chuy
# Processing Record 38 of Set 23 | craig
# Processing Record 39 of Set 23 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 23 | bajo baudo
# City not found. Skipping...
# Processing Record 41 of Set 23 | tonantins
# Processing Record 42 of Set 23 | kerteh
# City not found. Skipping...
# Processing Record 43 of Set 23 | altay
# Processing Record 44 of Set 23 | chara
# Processing Record 45 of Set 23 | dharchula
# Processing Record 46 of Set 23 | llanes
# Processing Record 47 of Set 23 | nakusp
# Processing Record 48 of Set 23 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 23 | bhuj
# Processing Record 50 of Set 23 | tsabong
# Processing Record 1 of Set 24 | evansville
# Processing Record 2 of Set 24 | tabou
# Processing Record 3 of Set 24 | natal
# Processing Record 4 of Set 24 | nizwa
# Processing Record 5 of Set 24 | hervey bay
# Processing Record 6 of Set 24 | bytosh
# Processing Record 7 of Set 24 | puerto escondido
# Processing Record 8 of Set 24 | zaraza
# Processing Record 9 of Set 24 | poum
# Processing Record 10 of Set 24 | richards bay
# Processing Record 11 of Set 24 | ponta delgada
# Processing Record 12 of Set 24 | gainesville
# Processing Record 13 of Set 24 | cockburn town
# Processing Record 14 of Set 24 | eureka
# Processing Record 15 of Set 24 | matagami
# Processing Record 16 of Set 24 | fairbanks
# Processing Record 17 of Set 24 | mangai
# Processing Record 18 of Set 24 | lensk
# Processing Record 19 of Set 24 | plouzane
# Processing Record 20 of Set 24 | gravdal
# Processing Record 21 of Set 24 | katsuura
# Processing Record 22 of Set 24 | mosquera
# Processing Record 23 of Set 24 | xining
# Processing Record 24 of Set 24 | grand gaube
# Processing Record 25 of Set 24 | constitucion
# Processing Record 26 of Set 24 | phalombe
# Processing Record 27 of Set 24 | port hedland
# Processing Record 28 of Set 24 | codrington
# Processing Record 29 of Set 24 | thio
# Processing Record 30 of Set 24 | anisoc
# Processing Record 31 of Set 24 | luganville
# Processing Record 32 of Set 24 | kyzyl-suu
# Processing Record 33 of Set 24 | corinto
# Processing Record 34 of Set 24 | boissevain
# Processing Record 35 of Set 24 | santo antonio do sudoeste
# Processing Record 36 of Set 24 | mahaicony
# City not found. Skipping...
# Processing Record 37 of Set 24 | pucallpa
# Processing Record 38 of Set 24 | mpika
# Processing Record 39 of Set 24 | charters towers
# Processing Record 40 of Set 24 | houma
# Processing Record 41 of Set 24 | matara
# Processing Record 42 of Set 24 | ferme-neuve
# Processing Record 43 of Set 24 | baiyin
# Processing Record 44 of Set 24 | broken hill
# Processing Record 45 of Set 24 | saint-georges
# Processing Record 46 of Set 24 | oxkutzcab
# Processing Record 47 of Set 24 | udachnyy
# Processing Record 48 of Set 24 | trinidad
# Processing Record 49 of Set 24 | ucluelet
# Processing Record 50 of Set 24 | nefteyugansk
# Processing Record 1 of Set 25 | kabelvag
# Processing Record 2 of Set 25 | mahibadhoo
# Processing Record 3 of Set 25 | keti bandar
# Processing Record 4 of Set 25 | kaduqli
# Processing Record 5 of Set 25 | launceston
# Processing Record 6 of Set 25 | bundaberg
# Processing Record 7 of Set 25 | bentiu
# Processing Record 8 of Set 25 | oistins
# Processing Record 9 of Set 25 | jos
# Processing Record 10 of Set 25 | moree
# Processing Record 11 of Set 25 | bathsheba
# Processing Record 12 of Set 25 | camacari
# Processing Record 13 of Set 25 | barranca de upia
# Processing Record 14 of Set 25 | bogorodskoye
# Processing Record 15 of Set 25 | turochak
# Processing Record 16 of Set 25 | saint anthony
# Processing Record 17 of Set 25 | sao filipe
# Processing Record 18 of Set 25 | qasigiannguit
# Processing Record 19 of Set 25 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa  22.0752 -159.3190     84.18        69          20
# 1    Rio Gallegos -51.6226  -69.2181     46.45        53           0
# 2      Bredasdorp -34.5322   20.0403     51.53        91          95
# 3  Guerrero Negro  27.9769 -114.0611     75.60        78           3
# 4       Sosenskiy  54.0590   35.9623     45.28        97         100
# 5      Hermosillo  29.0667 -110.9667     80.51        54         100
# 6         Talnakh  69.4865   88.3972     22.32        69          65
# 7      Nikolskoye  59.7035   30.7861     39.09        97          16
# 8        Hermanus -34.4187   19.2345     54.90        83          97
# 9          Castro -24.7911  -50.0119     58.71        98         100
#
#    Wind Speed Country                 Date
# 0       11.50      US  2022-09-28 03:21:30
# 1        8.05      AR  2022-09-28 03:21:31
# 2        4.07      ZA  2022-09-28 03:21:31
# 3       10.22      MX  2022-09-28 03:21:32
# 4        7.70      RU  2022-09-28 03:21:32
# 5       12.66      MX  2022-09-28 03:19:25
# 6        4.27      RU  2022-09-28 03:21:32
# 7        4.07      RU  2022-09-28 03:21:32
# 8        6.51      ZA  2022-09-28 03:21:33
# 9        6.51      BR  2022-09-28 03:17:24

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
reordered_city_data_df = city_data_df[new_column_order]
reordered_city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0           Kapaa      US  2022-09-28 03:21:30  22.0752 -159.3190     84.18
# 1    Rio Gallegos      AR  2022-09-28 03:21:31 -51.6226  -69.2181     46.45
# 2      Bredasdorp      ZA  2022-09-28 03:21:31 -34.5322   20.0403     51.53
# 3  Guerrero Negro      MX  2022-09-28 03:21:32  27.9769 -114.0611     75.60
# 4       Sosenskiy      RU  2022-09-28 03:21:32  54.0590   35.9623     45.28
# 5      Hermosillo      MX  2022-09-28 03:19:25  29.0667 -110.9667     80.51
# 6         Talnakh      RU  2022-09-28 03:21:32  69.4865   88.3972     22.32
# 7      Nikolskoye      RU  2022-09-28 03:21:32  59.7035   30.7861     39.09
# 8        Hermanus      ZA  2022-09-28 03:21:33 -34.4187   19.2345     54.90
# 9          Castro      BR  2022-09-28 03:17:24 -24.7911  -50.0119     58.71
#
#    Humidity  Cloudiness  Wind Speed
# 0        69          20       11.50
# 1        53           0        8.05
# 2        91          95        4.07
# 3        78           3       10.22
# 4        97         100        7.70
# 5        54         100       12.66
# 6        69          65        4.27
# 7        97          16        4.07
# 8        83          97        6.51
# 9        98         100        6.51

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Dikson
# Lat                       73.5069
# Lng                       80.5464
# Max Temp                    32.04
# Humidity                       74
# Cloudiness                     79
# Wind Speed                   5.84
# Country                        RU
# Date          2022-09-28 03:21:34
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 572     True
# 573     True
# 574     True
# 575     True
# 576     True
# Name: Lat, Length: 577, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa  22.0752 -159.3190     84.18        69          20
# 3  Guerrero Negro  27.9769 -114.0611     75.60        78           3
# 4       Sosenskiy  54.0590   35.9623     45.28        97         100
# 5      Hermosillo  29.0667 -110.9667     80.51        54         100
# 6         Talnakh  69.4865   88.3972     22.32        69          65
#
#    Wind Speed Country                 Date
# 0       11.50      US  2022-09-28 03:21:30
# 3       10.22      MX  2022-09-28 03:21:32
# 4        7.70      RU  2022-09-28 03:21:32
# 5       12.66      MX  2022-09-28 03:19:25
# 6        4.27      RU  2022-09-28 03:21:32

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(50,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-25,25))

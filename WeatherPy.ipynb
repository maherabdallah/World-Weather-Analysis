# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 633

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a7b251d269c2b5c876a648b2eb164c94

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | busselton
# Processing Record 2 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 13 | barmer
# Processing Record 4 of Set 13 | bredasdorp
# Processing Record 5 of Set 13 | harrison
# Processing Record 6 of Set 13 | ahipara
# Processing Record 7 of Set 13 | atar
# Processing Record 8 of Set 13 | flinders
# Processing Record 9 of Set 13 | ushuaia
# Processing Record 10 of Set 13 | homer
# Processing Record 11 of Set 13 | cape town
# Processing Record 12 of Set 13 | saskylakh
# Processing Record 13 of Set 13 | upernavik
# Processing Record 14 of Set 13 | georgetown
# Processing Record 15 of Set 13 | novopokrovka
# Processing Record 16 of Set 13 | wad madani
# Processing Record 17 of Set 13 | kampene
# Processing Record 18 of Set 13 | bluff
# Processing Record 19 of Set 13 | vaini
# Processing Record 20 of Set 13 | hobart
# Processing Record 21 of Set 13 | bandarbeyla
# Processing Record 22 of Set 13 | sioux lookout
# Processing Record 23 of Set 13 | batu
# Processing Record 24 of Set 13 | matamoros
# Processing Record 25 of Set 13 | chokurdakh
# Processing Record 26 of Set 13 | puerto ayora
# Processing Record 27 of Set 13 | new norfolk
# Processing Record 28 of Set 13 | rikitea
# Processing Record 29 of Set 13 | hithadhoo
# Processing Record 30 of Set 13 | laguna
# Processing Record 31 of Set 13 | avarua
# Processing Record 32 of Set 13 | tlacolula
# Processing Record 33 of Set 13 | barrow
# Processing Record 34 of Set 13 | oga
# Processing Record 35 of Set 13 | punta arenas
# Processing Record 36 of Set 13 | port alfred
# Processing Record 37 of Set 13 | atuona
# Processing Record 38 of Set 13 | longyearbyen
# Processing Record 39 of Set 13 | provideniya
# Processing Record 40 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 13 | chuy
# Processing Record 42 of Set 13 | belmonte
# Processing Record 43 of Set 13 | burnie
# Processing Record 44 of Set 13 | clyde river
# Processing Record 45 of Set 13 | kinango
# Processing Record 46 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 13 | namtsy
# Processing Record 48 of Set 13 | havre-saint-pierre
# Processing Record 49 of Set 13 | yar-sale
# Processing Record 50 of Set 13 | caravelas
# Processing Record 1 of Set 14 | santa cruz
# Processing Record 2 of Set 14 | xiamen
# Processing Record 3 of Set 14 | saint george
# Processing Record 4 of Set 14 | menemen
# Processing Record 5 of Set 14 | butaritari
# Processing Record 6 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 14 | mataura
# Processing Record 8 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 14 | henties bay
# Processing Record 10 of Set 14 | ilulissat
# Processing Record 11 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 14 | jamestown
# Processing Record 13 of Set 14 | pangoa
# Processing Record 14 of Set 14 | pak phanang
# Processing Record 15 of Set 14 | mareeba
# Processing Record 16 of Set 14 | olafsvik
# Processing Record 17 of Set 14 | itacoatiara
# Processing Record 18 of Set 14 | hamilton
# Processing Record 19 of Set 14 | hualmay
# Processing Record 20 of Set 14 | albany
# Processing Record 21 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 22 of Set 14 | yumen
# Processing Record 23 of Set 14 | castro
# Processing Record 24 of Set 14 | solhan
# Processing Record 25 of Set 14 | arraial do cabo
# Processing Record 26 of Set 14 | kuytun
# Processing Record 27 of Set 14 | vermilion
# Processing Record 28 of Set 14 | mar del plata
# Processing Record 29 of Set 14 | boyabat
# Processing Record 30 of Set 14 | fortuna
# Processing Record 31 of Set 14 | bambous virieux
# Processing Record 32 of Set 14 | namatanai
# Processing Record 33 of Set 14 | parras
# City not found. Skipping...
# Processing Record 34 of Set 14 | warri
# Processing Record 35 of Set 14 | victoria
# Processing Record 36 of Set 14 | kedrovyy
# Processing Record 37 of Set 14 | labuhan
# Processing Record 38 of Set 14 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 39 of Set 14 | luderitz
# Processing Record 40 of Set 14 | santa catarina de tepehuanes
# Processing Record 41 of Set 14 | carballo
# Processing Record 42 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 14 | talnakh
# Processing Record 44 of Set 14 | inca
# Processing Record 45 of Set 14 | ambam
# Processing Record 46 of Set 14 | kudahuvadhoo
# Processing Record 47 of Set 14 | abalak
# Processing Record 48 of Set 14 | atambua
# Processing Record 49 of Set 14 | atlantic city
# Processing Record 50 of Set 14 | inhambane
# Processing Record 1 of Set 15 | krasnoselkup
# Processing Record 2 of Set 15 | ponta do sol
# Processing Record 3 of Set 15 | tessalit
# Processing Record 4 of Set 15 | charters towers
# Processing Record 5 of Set 15 | lompoc
# Processing Record 6 of Set 15 | carnarvon
# Processing Record 7 of Set 15 | kahului
# Processing Record 8 of Set 15 | mweka
# Processing Record 9 of Set 15 | sitka
# Processing Record 10 of Set 15 | zadar
# Processing Record 11 of Set 15 | bennettsville
# Processing Record 12 of Set 15 | glinka
# Processing Record 13 of Set 15 | diu
# Processing Record 14 of Set 15 | senador jose porfirio
# Processing Record 15 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 15 | east london
# Processing Record 17 of Set 15 | mount isa
# Processing Record 18 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 15 | rundu
# Processing Record 20 of Set 15 | beisfjord
# Processing Record 21 of Set 15 | dikson
# Processing Record 22 of Set 15 | la rioja
# Processing Record 23 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 15 | tiznit
# Processing Record 25 of Set 15 | mayo
# Processing Record 26 of Set 15 | tombouctou
# Processing Record 27 of Set 15 | huanren
# Processing Record 28 of Set 15 | otukpo
# Processing Record 29 of Set 15 | hilo
# Processing Record 30 of Set 15 | mehamn
# Processing Record 31 of Set 15 | constitucion
# Processing Record 32 of Set 15 | ishigaki
# Processing Record 33 of Set 15 | nizhnedevitsk
# Processing Record 34 of Set 15 | barcelos
# Processing Record 35 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 15 | nam dinh
# Processing Record 37 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 15 | cherskiy
# Processing Record 39 of Set 15 | polunochnoye
# Processing Record 40 of Set 15 | coquimbo
# Processing Record 41 of Set 15 | soyo
# Processing Record 42 of Set 15 | bengkulu
# Processing Record 43 of Set 15 | leningradskiy
# Processing Record 44 of Set 15 | merauke
# Processing Record 45 of Set 15 | ginda
# Processing Record 46 of Set 15 | kendari
# Processing Record 47 of Set 15 | kapaa
# Processing Record 48 of Set 15 | hermanus
# Processing Record 49 of Set 15 | gamba
# Processing Record 50 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 16 | gornyak
# Processing Record 2 of Set 16 | bowen
# Processing Record 3 of Set 16 | ayan
# Processing Record 4 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 16 | paita
# Processing Record 6 of Set 16 | lebu
# Processing Record 7 of Set 16 | kaitangata
# Processing Record 8 of Set 16 | vila velha
# Processing Record 9 of Set 16 | cine
# Processing Record 10 of Set 16 | fort nelson
# Processing Record 11 of Set 16 | tasiilaq
# Processing Record 12 of Set 16 | salinopolis
# Processing Record 13 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 16 | cap malheureux
# Processing Record 15 of Set 16 | bjornevatn
# Processing Record 16 of Set 16 | asandh
# Processing Record 17 of Set 16 | torbay
# Processing Record 18 of Set 16 | khatanga
# Processing Record 19 of Set 16 | tucumcari
# Processing Record 20 of Set 16 | kungurtug
# Processing Record 21 of Set 16 | vila do maio
# Processing Record 22 of Set 16 | sonoita
# Processing Record 23 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 16 | college
# Processing Record 25 of Set 16 | newcastle
# Processing Record 26 of Set 16 | lavrentiya
# Processing Record 27 of Set 16 | pevek
# Processing Record 28 of Set 16 | iqaluit
# Processing Record 29 of Set 16 | abohar
# Processing Record 30 of Set 16 | baghdad
# Processing Record 31 of Set 16 | carupano
# Processing Record 32 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 16 | emba
# Processing Record 34 of Set 16 | nieuw nickerie
# Processing Record 35 of Set 16 | kibondo
# Processing Record 36 of Set 16 | chapais
# Processing Record 37 of Set 16 | aljezur
# Processing Record 38 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 16 | port elizabeth
# Processing Record 40 of Set 16 | bako
# Processing Record 41 of Set 16 | san cristobal
# Processing Record 42 of Set 16 | abonnema
# Processing Record 43 of Set 16 | sadasivpet
# Processing Record 44 of Set 16 | lorengau
# Processing Record 45 of Set 16 | palmer
# Processing Record 46 of Set 16 | norrtalje
# Processing Record 47 of Set 16 | katsuura
# Processing Record 48 of Set 16 | shingu
# Processing Record 49 of Set 16 | ahuimanu
# Processing Record 50 of Set 16 | port hardy
# Processing Record 1 of Set 17 | north bend
# Processing Record 2 of Set 17 | chuzhou
# Processing Record 3 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 17 | arteaga
# Processing Record 5 of Set 17 | verkhneuralsk
# Processing Record 6 of Set 17 | englewood
# Processing Record 7 of Set 17 | sao filipe
# Processing Record 8 of Set 17 | portland
# Processing Record 9 of Set 17 | santa vitoria do palmar
# Processing Record 10 of Set 17 | nikolskoye
# Processing Record 11 of Set 17 | pietarsaari
# Processing Record 12 of Set 17 | barinas
# Processing Record 13 of Set 17 | tuktoyaktuk
# Processing Record 14 of Set 17 | tianpeng
# Processing Record 15 of Set 17 | qaanaaq
# Processing Record 16 of Set 17 | novosheshminsk
# Processing Record 17 of Set 17 | taksimo
# Processing Record 18 of Set 17 | huejuquilla el alto
# Processing Record 19 of Set 17 | suluq
# Processing Record 20 of Set 17 | vila franca do campo
# Processing Record 21 of Set 17 | dyersburg
# Processing Record 22 of Set 17 | nyuksenitsa
# Processing Record 23 of Set 17 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 17 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 17 | davila
# Processing Record 26 of Set 17 | chum phae
# Processing Record 27 of Set 17 | fier
# Processing Record 28 of Set 17 | banyuwangi
# Processing Record 29 of Set 17 | cedar city
# Processing Record 30 of Set 17 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 17 | buchanan
# Processing Record 32 of Set 17 | kanker
# Processing Record 33 of Set 17 | omsukchan
# Processing Record 34 of Set 17 | chabahar
# Processing Record 35 of Set 17 | caen
# Processing Record 36 of Set 17 | prainha
# Processing Record 37 of Set 17 | namibe
# Processing Record 38 of Set 17 | caucaia
# Processing Record 39 of Set 17 | elizabeth city
# Processing Record 40 of Set 17 | grand gaube
# Processing Record 41 of Set 17 | odessa
# Processing Record 42 of Set 17 | beloha
# Processing Record 43 of Set 17 | kavaratti
# Processing Record 44 of Set 17 | saint-georges
# Processing Record 45 of Set 17 | krieglach
# Processing Record 46 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 17 | acapulco
# Processing Record 48 of Set 17 | pedernales
# Processing Record 49 of Set 17 | belaya gora
# Processing Record 50 of Set 17 | yaransk
# Processing Record 1 of Set 18 | la palma
# Processing Record 2 of Set 18 | panjakent
# Processing Record 3 of Set 18 | maldonado
# Processing Record 4 of Set 18 | ostrovnoy
# Processing Record 5 of Set 18 | youghal
# Processing Record 6 of Set 18 | vestmannaeyjar
# Processing Record 7 of Set 18 | tuatapere
# Processing Record 8 of Set 18 | foki
# Processing Record 9 of Set 18 | erzurum
# Processing Record 10 of Set 18 | kupang
# Processing Record 11 of Set 18 | narsaq
# Processing Record 12 of Set 18 | tura
# Processing Record 13 of Set 18 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 18 | inuvik
# Processing Record 15 of Set 18 | hobyo
# Processing Record 16 of Set 18 | kaniama
# Processing Record 17 of Set 18 | luang prabang
# Processing Record 18 of Set 18 | surt
# Processing Record 19 of Set 18 | havoysund
# Processing Record 20 of Set 18 | koungou
# Processing Record 21 of Set 18 | touros
# Processing Record 22 of Set 18 | kodinsk
# Processing Record 23 of Set 18 | kavieng
# Processing Record 24 of Set 18 | pangnirtung
# Processing Record 25 of Set 18 | samarai
# Processing Record 26 of Set 18 | naze
# Processing Record 27 of Set 18 | brae
# Processing Record 28 of Set 18 | pervomayskoye
# Processing Record 29 of Set 18 | sujiatun
# Processing Record 30 of Set 18 | kiunga
# Processing Record 31 of Set 18 | talaya
# Processing Record 32 of Set 18 | ola
# Processing Record 33 of Set 18 | beaverlodge
# Processing Record 34 of Set 18 | geraldton
# Processing Record 35 of Set 18 | sorong
# Processing Record 36 of Set 18 | deputatskiy
# Processing Record 37 of Set 18 | faanui
# Processing Record 38 of Set 18 | thompson
# Processing Record 39 of Set 18 | abha
# Processing Record 40 of Set 18 | kruisfontein
# Processing Record 41 of Set 18 | causapscal
# Processing Record 42 of Set 18 | hargeysa
# Processing Record 43 of Set 18 | tiksi
# Processing Record 44 of Set 18 | saint-pierre
# Processing Record 45 of Set 18 | flin flon
# Processing Record 46 of Set 18 | egvekinot
# Processing Record 47 of Set 18 | parkes
# Processing Record 48 of Set 18 | bagarji
# Processing Record 49 of Set 18 | zhangye
# Processing Record 50 of Set 18 | arica
# Processing Record 1 of Set 19 | yellowknife
# Processing Record 2 of Set 19 | kerema
# Processing Record 3 of Set 19 | khomutovo
# Processing Record 4 of Set 19 | cayenne
# Processing Record 5 of Set 19 | eureka
# Processing Record 6 of Set 19 | the valley
# Processing Record 7 of Set 19 | dongning
# Processing Record 8 of Set 19 | tambopata
# Processing Record 9 of Set 19 | ta khmau
# Processing Record 10 of Set 19 | jacqueville
# Processing Record 11 of Set 19 | pahrump
# Processing Record 12 of Set 19 | saint-philippe
# Processing Record 13 of Set 19 | kodiak
# Processing Record 14 of Set 19 | opatija
# Processing Record 15 of Set 19 | vilyuysk
# Processing Record 16 of Set 19 | chumikan
# Processing Record 17 of Set 19 | la ronge
# Processing Record 18 of Set 19 | lucapa
# Processing Record 19 of Set 19 | mahibadhoo
# Processing Record 20 of Set 19 | vao
# Processing Record 21 of Set 19 | ranipur
# Processing Record 22 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 19 | fujin
# Processing Record 24 of Set 19 | myingyan
# Processing Record 25 of Set 19 | zonguldak
# Processing Record 26 of Set 19 | kasongo-lunda
# Processing Record 27 of Set 19 | panlaitan
# Processing Record 28 of Set 19 | porto santo
# Processing Record 29 of Set 19 | pecos
# Processing Record 30 of Set 19 | mao
# Processing Record 31 of Set 19 | poum
# Processing Record 32 of Set 19 | tilichiki
# Processing Record 33 of Set 19 | broome
# Processing Record 34 of Set 19 | anadyr
# Processing Record 35 of Set 19 | bayonne
# Processing Record 36 of Set 19 | verkhoyansk
# Processing Record 37 of Set 19 | moose factory
# Processing Record 38 of Set 19 | gulshat
# City not found. Skipping...
# Processing Record 39 of Set 19 | nanortalik
# Processing Record 40 of Set 19 | oarai
# Processing Record 41 of Set 19 | puqi
# Processing Record 42 of Set 19 | kununurra
# Processing Record 43 of Set 19 | alyangula
# Processing Record 44 of Set 19 | lady lake
# Processing Record 45 of Set 19 | port-gentil
# Processing Record 46 of Set 19 | cidreira
# Processing Record 47 of Set 19 | evensk
# Processing Record 48 of Set 19 | miramar
# Processing Record 49 of Set 19 | nantucket
# Processing Record 50 of Set 19 | harlingen
# Processing Record 1 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 20 | owando
# Processing Record 3 of Set 20 | pacific grove
# Processing Record 4 of Set 20 | airai
# Processing Record 5 of Set 20 | yuza
# Processing Record 6 of Set 20 | avera
# Processing Record 7 of Set 20 | canaries
# Processing Record 8 of Set 20 | calama
# Processing Record 9 of Set 20 | namyslow
# Processing Record 10 of Set 20 | makakilo city
# Processing Record 11 of Set 20 | cabra
# Processing Record 12 of Set 20 | oktyabrskiy
# Processing Record 13 of Set 20 | souillac
# Processing Record 14 of Set 20 | matara
# Processing Record 15 of Set 20 | merrill
# Processing Record 16 of Set 20 | poltavskaya
# Processing Record 17 of Set 20 | kismayo
# Processing Record 18 of Set 20 | shubarshi
# Processing Record 19 of Set 20 | hrodna
# Processing Record 20 of Set 20 | oriximina
# Processing Record 21 of Set 20 | ambilobe
# Processing Record 22 of Set 20 | skeldon
# Processing Record 23 of Set 20 | sept-iles
# Processing Record 24 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 20 | mananjary
# Processing Record 26 of Set 20 | lata
# Processing Record 27 of Set 20 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 20 | tahta
# Processing Record 29 of Set 20 | ust-kulom
# Processing Record 30 of Set 20 | wuchi
# Processing Record 31 of Set 20 | te anau
# Processing Record 32 of Set 20 | auki
# Processing Record 33 of Set 20 | rexburg
# Processing Record 34 of Set 20 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 20 | san patricio
# Processing Record 36 of Set 20 | amuntai
# Processing Record 37 of Set 20 | seoul
# Processing Record 38 of Set 20 | tucuma
# Processing Record 39 of Set 20 | ialibu
# Processing Record 40 of Set 20 | sur
# Processing Record 41 of Set 20 | shambu
# Processing Record 42 of Set 20 | timmins
# Processing Record 43 of Set 20 | port maria
# Processing Record 44 of Set 20 | camocim
# Processing Record 45 of Set 20 | cortez
# Processing Record 46 of Set 20 | monrovia
# Processing Record 47 of Set 20 | rio grande
# Processing Record 48 of Set 20 | bathsheba
# Processing Record 49 of Set 20 | dukat
# Processing Record 50 of Set 20 | mazagao
# Processing Record 1 of Set 21 | llanes
# Processing Record 2 of Set 21 | okhotsk
# Processing Record 3 of Set 21 | athens
# Processing Record 4 of Set 21 | mattru
# Processing Record 5 of Set 21 | mezen
# Processing Record 6 of Set 21 | hun
# Processing Record 7 of Set 21 | chekhov
# Processing Record 8 of Set 21 | huntingdon
# Processing Record 9 of Set 21 | plouzane
# Processing Record 10 of Set 21 | marystown
# Processing Record 11 of Set 21 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 21 | worland
# Processing Record 13 of Set 21 | ranong
# Processing Record 14 of Set 21 | klaksvik
# Processing Record 15 of Set 21 | santa rosalia
# Processing Record 16 of Set 21 | waingapu
# Processing Record 17 of Set 21 | arawa
# Processing Record 18 of Set 21 | codrington
# Processing Record 19 of Set 21 | mataram
# Processing Record 20 of Set 21 | isangel
# Processing Record 21 of Set 21 | norman wells
# Processing Record 22 of Set 21 | sredniy ikorets
# Processing Record 23 of Set 21 | mandalgovi
# Processing Record 24 of Set 21 | ancud
# Processing Record 25 of Set 21 | ayaviri
# Processing Record 26 of Set 21 | fairbanks
# Processing Record 27 of Set 21 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 21 | chapleau
# Processing Record 29 of Set 21 | bahir dar
# Processing Record 30 of Set 21 | kerteh
# City not found. Skipping...
# Processing Record 31 of Set 21 | batticaloa
# Processing Record 32 of Set 21 | ankang
# Processing Record 33 of Set 21 | prestea
# Processing Record 34 of Set 21 | dauriya
# Processing Record 35 of Set 21 | marathopolis
# City not found. Skipping...
# Processing Record 36 of Set 21 | vryheid
# Processing Record 37 of Set 21 | marv dasht
# City not found. Skipping...
# Processing Record 38 of Set 21 | saldanha
# Processing Record 39 of Set 21 | bokspits
# City not found. Skipping...
# Processing Record 40 of Set 21 | karimnagar
# Processing Record 41 of Set 21 | ust-ilimsk
# Processing Record 42 of Set 21 | manaure
# Processing Record 43 of Set 21 | alofi
# Processing Record 44 of Set 21 | quatre cocos
# Processing Record 45 of Set 21 | dali
# Processing Record 46 of Set 21 | saint-joseph
# Processing Record 47 of Set 21 | san carlos de bariloche
# Processing Record 48 of Set 21 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 49 of Set 21 | griffith
# Processing Record 50 of Set 21 | pitimbu
# Processing Record 1 of Set 22 | hofn
# Processing Record 2 of Set 22 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 22 | morro bay
# Processing Record 4 of Set 22 | ust-maya
# Processing Record 5 of Set 22 | bethel
# Processing Record 6 of Set 22 | tecoanapa
# Processing Record 7 of Set 22 | port blair
# Processing Record 8 of Set 22 | esperance
# Processing Record 9 of Set 22 | kochubey
# Processing Record 10 of Set 22 | arklow
# Processing Record 11 of Set 22 | akyab
# Processing Record 12 of Set 22 | tabuk
# Processing Record 13 of Set 22 | dauphin
# Processing Record 14 of Set 22 | shalinskoye
# Processing Record 15 of Set 22 | sorkjosen
# Processing Record 16 of Set 22 | zhigansk
# Processing Record 17 of Set 22 | arman
# Processing Record 18 of Set 22 | gat
# Processing Record 19 of Set 22 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 22 | kerman
# Processing Record 21 of Set 22 | cabo san lucas
# Processing Record 22 of Set 22 | port keats
# Processing Record 23 of Set 22 | sovetsk
# Processing Record 24 of Set 22 | hovd
# Processing Record 25 of Set 22 | grindavik
# Processing Record 26 of Set 22 | ribeira grande
# Processing Record 27 of Set 22 | naryan-mar
# Processing Record 28 of Set 22 | quelimane
# Processing Record 29 of Set 22 | toloa adentro
# City not found. Skipping...
# Processing Record 30 of Set 22 | ouegoa
# Processing Record 31 of Set 22 | hervey bay
# Processing Record 32 of Set 22 | la paz
# Processing Record 33 of Set 22 | ibra
# Processing Record 34 of Set 22 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 22 | dunedin
# Processing Record 36 of Set 22 | likasi
# Processing Record 37 of Set 22 | rodrigues alves
# Processing Record 38 of Set 22 | kirakira
# Processing Record 39 of Set 22 | ngama
# Processing Record 40 of Set 22 | yatou
# Processing Record 41 of Set 22 | rio gallegos
# Processing Record 42 of Set 22 | nadym
# Processing Record 43 of Set 22 | hit
# Processing Record 44 of Set 22 | turukhansk
# Processing Record 45 of Set 22 | sao jose da coroa grande
# Processing Record 46 of Set 22 | palmeira
# Processing Record 47 of Set 22 | mount gambier
# Processing Record 48 of Set 22 | halifax
# Processing Record 49 of Set 22 | scottsbluff
# Processing Record 50 of Set 22 | mayumba
# Processing Record 1 of Set 23 | chepareria
# Processing Record 2 of Set 23 | vallenar
# Processing Record 3 of Set 23 | sao joao da barra
# Processing Record 4 of Set 23 | saint-augustin
# Processing Record 5 of Set 23 | trairi
# Processing Record 6 of Set 23 | jaciara
# Processing Record 7 of Set 23 | effium
# Processing Record 8 of Set 23 | paamiut
# Processing Record 9 of Set 23 | maarianhamina
# Processing Record 10 of Set 23 | nam tha
# City not found. Skipping...
# Processing Record 11 of Set 23 | riyadh
# Processing Record 12 of Set 23 | kilindoni
# Processing Record 13 of Set 23 | bilibino
# Processing Record 14 of Set 23 | comodoro rivadavia
# Processing Record 15 of Set 23 | coihaique
# Processing Record 16 of Set 23 | banyo
# Processing Record 17 of Set 23 | bereda
# Processing Record 18 of Set 23 | ivdel
# Processing Record 19 of Set 23 | udachnyy
# Processing Record 20 of Set 23 | ugoofaaru
# Processing Record 21 of Set 23 | tabriz
# Processing Record 22 of Set 23 | hami
# Processing Record 23 of Set 23 | atbasar
# Processing Record 24 of Set 23 | mahebourg
# Processing Record 25 of Set 23 | camacha
# Processing Record 26 of Set 23 | rocha
# Processing Record 27 of Set 23 | kirovskiy
# Processing Record 28 of Set 23 | diamantino
# Processing Record 29 of Set 23 | ocos
# Processing Record 30 of Set 23 | puerto padre
# Processing Record 31 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 23 | clinton
# Processing Record 33 of Set 23 | joinville
# Processing Record 34 of Set 23 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 23 | andenes
# Processing Record 36 of Set 23 | balkanabat
# Processing Record 37 of Set 23 | bam
# Processing Record 38 of Set 23 | beringovskiy
# Processing Record 39 of Set 23 | grivenskaya
# Processing Record 40 of Set 23 | grand-santi
# Processing Record 41 of Set 23 | chegdomyn
# Processing Record 42 of Set 23 | lagoa
# Processing Record 43 of Set 23 | puerto del rosario
# Processing Record 44 of Set 23 | doha
# Processing Record 45 of Set 23 | alice springs
# Processing Record 46 of Set 23 | kandri
# Processing Record 47 of Set 23 | hasaki
# Processing Record 48 of Set 23 | monterey
# Processing Record 49 of Set 23 | sakakah
# Processing Record 50 of Set 23 | bud
# Processing Record 1 of Set 24 | aykhal
# Processing Record 2 of Set 24 | swanton
# Processing Record 3 of Set 24 | chone
# Processing Record 4 of Set 24 | minab
# Processing Record 5 of Set 24 | shenjiamen
# Processing Record 6 of Set 24 | udon thani
# Processing Record 7 of Set 24 | bulgan
# Processing Record 8 of Set 24 | pisco
# Processing Record 9 of Set 24 | jalu
# Processing Record 10 of Set 24 | ixtapa
# Processing Record 11 of Set 24 | lakatoro
# Processing Record 12 of Set 24 | taree
# Processing Record 13 of Set 24 | aklavik
# Processing Record 14 of Set 24 | haines junction
# Processing Record 15 of Set 24 | qasigiannguit
# Processing Record 16 of Set 24 | ofaqim
# Processing Record 17 of Set 24 | saint-michel-des-saints
# Processing Record 18 of Set 24 | waddan
# Processing Record 19 of Set 24 | guerrero negro
# Processing Record 20 of Set 24 | rovaniemi
# Processing Record 21 of Set 24 | sobolevo
# Processing Record 22 of Set 24 | lantawan
# Processing Record 23 of Set 24 | bathurst
# Processing Record 24 of Set 24 | nishihara
# Processing Record 25 of Set 24 | jabinyanah
# Processing Record 26 of Set 24 | southbridge
# Processing Record 27 of Set 24 | bodden town
# Processing Record 28 of Set 24 | adrar
# Processing Record 29 of Set 24 | kondinskoye
# Processing Record 30 of Set 24 | wuan
# Processing Record 31 of Set 24 | jiaocheng
# Processing Record 32 of Set 24 | lensk
# Processing Record 33 of Set 24 | arnes
# Processing Record 34 of Set 24 | cockburn town
# Processing Record 35 of Set 24 | ingham
# Processing Record 36 of Set 24 | redding
# Processing Record 37 of Set 24 | tigil
# Processing Record 38 of Set 24 | kavant
# City not found. Skipping...
# Processing Record 39 of Set 24 | jizan
# Processing Record 40 of Set 24 | mariental
# Processing Record 41 of Set 24 | kisangani
# Processing Record 42 of Set 24 | naantali
# Processing Record 43 of Set 24 | harper
# Processing Record 44 of Set 24 | imeni poliny osipenko
# Processing Record 45 of Set 24 | severo-kurilsk
# Processing Record 46 of Set 24 | lethem
# Processing Record 47 of Set 24 | mabaruma
# Processing Record 48 of Set 24 | tirat karmel
# Processing Record 49 of Set 24 | forio
# Processing Record 50 of Set 24 | san quintin
# Processing Record 1 of Set 25 | linguere
# Processing Record 2 of Set 25 | maceio
# Processing Record 3 of Set 25 | vardo
# Processing Record 4 of Set 25 | itupiranga
# Processing Record 5 of Set 25 | kamphaeng phet
# Processing Record 6 of Set 25 | werda
# Processing Record 7 of Set 25 | nkoteng
# Processing Record 8 of Set 25 | gladstone
# Processing Record 9 of Set 25 | san blas
# Processing Record 10 of Set 25 | meulaboh
# Processing Record 11 of Set 25 | alvand
# Processing Record 12 of Set 25 | putina
# Processing Record 13 of Set 25 | poddorye
# Processing Record 14 of Set 25 | mackay
# Processing Record 15 of Set 25 | tafresh
# Processing Record 16 of Set 25 | donnacona
# Processing Record 17 of Set 25 | sibolga
# Processing Record 18 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 25 | lysva
# Processing Record 20 of Set 25 | mapiripan
# Processing Record 21 of Set 25 | kearney
# Processing Record 22 of Set 25 | papasquiaro
# City not found. Skipping...
# Processing Record 23 of Set 25 | cumberland
# Processing Record 24 of Set 25 | arrecife
# Processing Record 25 of Set 25 | andevoranto
# City not found. Skipping...
# Processing Record 26 of Set 25 | salym
# Processing Record 27 of Set 25 | todos santos
# Processing Record 28 of Set 25 | nyanza
# Processing Record 29 of Set 25 | puncan
# Processing Record 30 of Set 25 | shache
# Processing Record 31 of Set 25 | lubango
# Processing Record 32 of Set 25 | erie
# Processing Record 33 of Set 25 | kindu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Busselton -33.6500  115.3333     56.25        82          48        9.15
# 1      Barmer  25.7500   71.3833     80.35        53           9        7.87
# 2  Bredasdorp -34.5322   20.0403     51.46        91          21        2.71
# 3    Harrison  30.4091  -89.0436     80.67        31           0       13.80
# 4     Ahipara -35.1667  173.1667     63.79        68         100       12.37
# 5        Atar  20.5169  -13.0499     94.26        35          67        4.85
# 6    Flinders -34.5833  150.8552     64.18        88          85        5.01
# 7     Ushuaia -54.8000  -68.3000     44.26        76          75       27.63
# 8       Homer  59.6425 -151.5483     51.69        61          75        5.75
# 9   Cape Town -33.9258   18.4232     56.12        83           0        2.30
#
#   Country                 Date
# 0      AU  2022-09-27 23:35:06
# 1      IN  2022-09-27 23:35:06
# 2      ZA  2022-09-27 23:31:15
# 3      US  2022-09-27 23:35:07
# 4      NZ  2022-09-27 23:35:07
# 5      MR  2022-09-27 23:30:08
# 6      AU  2022-09-27 23:35:08
# 7      AR  2022-09-27 23:35:08
# 8      US  2022-09-27 23:35:08
# 9      ZA  2022-09-27 23:35:08

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
reordered_city_data_df = city_data_df[new_column_order]
reordered_city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0   Busselton      AU  2022-09-27 23:35:06 -33.6500  115.3333     56.25
# 1      Barmer      IN  2022-09-27 23:35:06  25.7500   71.3833     80.35
# 2  Bredasdorp      ZA  2022-09-27 23:31:15 -34.5322   20.0403     51.46
# 3    Harrison      US  2022-09-27 23:35:07  30.4091  -89.0436     80.67
# 4     Ahipara      NZ  2022-09-27 23:35:07 -35.1667  173.1667     63.79
# 5        Atar      MR  2022-09-27 23:30:08  20.5169  -13.0499     94.26
# 6    Flinders      AU  2022-09-27 23:35:08 -34.5833  150.8552     64.18
# 7     Ushuaia      AR  2022-09-27 23:35:08 -54.8000  -68.3000     44.26
# 8       Homer      US  2022-09-27 23:35:08  59.6425 -151.5483     51.69
# 9   Cape Town      ZA  2022-09-27 23:35:08 -33.9258   18.4232     56.12
#
#    Humidity  Cloudiness  Wind Speed
# 0        82          48        9.15
# 1        53           9        7.87
# 2        91          21        2.71
# 3        31           0       13.80
# 4        68         100       12.37
# 5        35          67        4.85
# 6        88          85        5.01
# 7        76          75       27.63
# 8        61          75        5.75
# 9        83           0        2.30

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
